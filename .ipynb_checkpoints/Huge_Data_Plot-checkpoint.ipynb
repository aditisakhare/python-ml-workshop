# %%
from bokeh.charts import Scatter, output_file, show
import pandas
# Out:
# c:\users\aditi\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\util\deprecation.py:34: BokehDeprecationWarning:
# The bokeh.charts API has moved to a separate 'bkcharts' package.
#
# This compatibility shim will remain until Bokeh 1.0 is released.
# After that, if you want to use this API you will have to install
# the bkcharts package explicitly.
#
#   warn(message)

# %%
df = pandas.read_excel("verlegenhuken.xlsx",sheetname=0)
df
# Out:
#        Year  Month  Day  Hour  Temperature  Pressure
# 0      2010     10    6     3          -30      9984
# 1      2010     10    6     9          -28      9992
# 2      2010     10    6    10          -24      9987
# 3      2010     10    6    11          -19      9987
# 4      2010     10    6    12          -19      9985
# 5      2010     10    6    13          -20      9982
# 6      2010     10    6    14          -15      9975
# 7      2010     10    6    15           -8      9971
# 8      2010     10    6    16           -5      9960
# 9      2010     10    6    17          -12      9953
# 10     2010     10    6    18          -13      9946
# 11     2010     10    6    19          -15      9937
# 12     2010     10    6    20           -7      9928
# 13     2010     10    6    21            1      9924
# 14     2010     10    6    22            5      9924
# 15     2010     10    6    23            5      9921
# 16     2010     10    7     0           11      9922
# ...

# %%
# Using ChartsInterface

df["Temperature"]=df["Temperature"]
df["Pressure"]=df["Pressure"]

p=Scatter(df,x="Temperature",y="Pressure",xlabel="Temperature",ylabel="Pressure(hPa)",title="Temperature and Air Pressure")
output_file("Weather_charts.html")
show(p)

# %%
# Using PlottibgInterface

p=figure(plot_width=500,plot_height=400,tools='pan,resize',logo=None,title="Temperature and Air Pressure")

p.circle(df["Temperature"],df["Pressure"],size=0.5)
output_file("Weather_plot.html")
show(p)
